# %% [markdown]
# <a href="https://colab.research.google.com/github/unknown724/game/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install necessary libraries
# !pip install folium

# Import required libraries
import folium
from google.colab import files

# List of the top 20 most visited cities with visitors (in millions) and coordinates
most_visited_cities = [
    {"rank": 1, "city": "Bangkok", "country": "Thailand", "visitors": 22.78, "lat": 13.7563, "lon": 100.5018},
    {"rank": 2, "city": "Paris", "country": "France", "visitors": 19.10, "lat": 48.8566, "lon": 2.3522},
    {"rank": 3, "city": "London", "country": "United Kingdom", "visitors": 19.09, "lat": 51.5074, "lon": -0.1278},
    {"rank": 4, "city": "Dubai", "country": "UAE", "visitors": 15.93, "lat": 25.276987, "lon": 55.296249},
    {"rank": 5, "city": "Singapore", "country": "Singapore", "visitors": 14.67, "lat": 1.3521, "lon": 103.8198},
    {"rank": 6, "city": "New York", "country": "USA", "visitors": 13.60, "lat": 40.7128, "lon": -74.0060},
    {"rank": 7, "city": "Kuala Lumpur", "country": "Malaysia", "visitors": 13.43, "lat": 3.1390, "lon": 101.6869},
    {"rank": 8, "city": "Tokyo", "country": "Japan", "visitors": 12.93, "lat": 35.6895, "lon": 139.6917},
    {"rank": 9, "city": "Istanbul", "country": "Turkey", "visitors": 12.80, "lat": 41.0082, "lon": 28.9784},
    {"rank": 10, "city": "Seoul", "country": "South Korea", "visitors": 12.40, "lat": 37.5665, "lon": 126.9780},
    {"rank": 11, "city": "Antalya", "country": "Turkey", "visitors": 11.27, "lat": 36.8969, "lon": 30.7133},
    {"rank": 12, "city": "Phuket", "country": "Thailand", "visitors": 10.54, "lat": 7.8804, "lon": 98.3923},
    {"rank": 13, "city": "Mecca", "country": "Saudi Arabia", "visitors": 10.00, "lat": 21.3891, "lon": 39.8579},
    {"rank": 14, "city": "Pattaya", "country": "Thailand", "visitors": 9.44, "lat": 12.9236, "lon": 100.8825},
    {"rank": 15, "city": "Milan", "country": "Italy", "visitors": 9.10, "lat": 45.4642, "lon": 9.1900},
    {"rank": 16, "city": "Barcelona", "country": "Spain", "visitors": 8.89, "lat": 41.3851, "lon": 2.1734},
    {"rank": 17, "city": "Palma de Mallorca", "country": "Spain", "visitors": 8.79, "lat": 39.5696, "lon": 2.6502},
    {"rank": 18, "city": "Bali", "country": "Indonesia", "visitors": 8.26, "lat": -8.3405, "lon": 115.0920},
    {"rank": 19, "city": "Hong Kong", "country": "China", "visitors": 8.24, "lat": 22.3193, "lon": 114.1694},
    {"rank": 20, "city": "Mumbai", "country": "India", "visitors": 7.97, "lat": 19.0760, "lon": 72.8777},
]

# Create a world map centered at an approximate location
world_map = folium.Map(location=[20, 0], zoom_start=2, tiles="cartodb positron")

# Add markers for each city
for city in most_visited_cities:
    popup_text = f"""
    <b>{city['city']}, {city['country']}</b><br>
    🌍 Rank: {city['rank']}<br>
    👥 Visitors: {city['visitors']} Million
    """
    folium.Marker(
        location=[city["lat"], city["lon"]],
        popup=folium.Popup(popup_text, max_width=300),
        tooltip=f"{city['city']} (Click for details)",
        icon=folium.Icon(color="blue", icon="cloud")
    ).add_to(world_map)

# Save the map as an HTML file
map_filename = "most_visited_cities_map.html"
world_map.save(map_filename)

# Provide a download link for the generated map
files.download(map_filename)

# Display the interactive map in Colab
world_map
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.11/dist-packages (0.19.4)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.11/dist-packages (from folium) (3.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.11/dist-packages (from folium) (2025.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2024.12.14)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c523498622270f0b663755cb00d6a391 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c523498622270f0b663755cb00d6a391&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c523498622270f0b663755cb00d6a391 = L.map(
#                 &quot;map_c523498622270f0b663755cb00d6a391&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a6f48dfe79aac54e021628f00328477f = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a6f48dfe79aac54e021628f00328477f.addTo(map_c523498622270f0b663755cb00d6a391);
#
#
#             var marker_2ca6d2998db44624bd6321cc3ca6e5a5 = L.marker(
#                 [13.7563, 100.5018],
#                 {
# }
#             ).addTo(map_c523498622270f0b663755cb00d6a391);
#
#
#             var icon_d03f1f38aea9aff01d9ee8bcf8b76b05 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_2ca6d2998db44624bd6321cc3ca6e5a5.setIcon(icon_d03f1f38aea9aff01d9ee8bcf8b76b05);
#
#
#         var popup_914d5582381b211e5acd210798fa3546 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_f3f603cb5d3dabc6cbfd668f1a8616a0 = $(`&lt;div id=&quot;html_f3f603cb5d3dabc6cbfd668f1a8616a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Bangkok, Thailand&lt;/b&gt;&lt;br&gt;     🌍 Rank: 1&lt;br&gt;     👥 Visitors: 22.78 Million     &lt;/div&gt;`)[0];
#                 popup_914d5582381b211e5acd210798fa3546.setContent(html_f3f603cb5d3dabc6cbfd668f1a8616a0);
#
#
#
#         marker_2ca6d2998db44624bd6321cc3ca6e5a5.bindPopup(popup_914d5582381b211e5acd210798fa3546)
#         ;
#
#
#
#
#             marker_2ca6d2998db44624bd6321cc3ca6e5a5.bindTooltip(
#                 `&lt;div&gt;
#                      Bangkok (Click for details)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_48fc05eabd48c51e329de51bba63de69 = L.marker(
#                 [48.8566, 2.3522],
#                 {
# }
#             ).addTo(map_c523498622270f0b663755cb00d6a391);
#
#
#             var icon_672838a4574b60fc85204c64ff0bd979 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_48fc05eabd48c51e329de51bba63de69.setIcon(icon_672838a4574b60fc85204c64ff0bd979);
#
#
#         var popup_6b08a542342daad642c848d46fb88f60 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_5844dee6c47be954ed432cf11e62fe87 = $(`&lt;div id=&quot;html_5844dee6c47be954ed432cf11e62fe87&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Paris, France&lt;/b&gt;&lt;br&gt;     🌍 Rank: 2&lt;br&gt;     👥 Visitors: 19.1 Million     &lt;/div&gt;`)[0];
#                 popup_6b08a542342daad642c848d46fb88f60.setContent(html_5844dee6c47be954ed432cf11e62fe87);
#
#
#
#         marker_48fc05eabd48c51e329de51bba63de69.bindPopup(popup_6b08a542342daad642c848d46fb88f60)
#         ;
#
#
#
#
#             marker_48fc05eabd48c51e329de51bba63de69.bindTooltip(
#                 `&lt;div&gt;
#                      Paris (Click for details)
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_a7d3c1d746a368334b1a5496c6cecbf9 = L.marker(
#                 [51.5074, -0.1278],
#                 {
# }
#             ).addTo(map_c523498622270f0b663755cb00d6a391);
#
#
#             var icon_c7de65cc3ca2947c1f7892f141181003 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_a7d3c1d746a368334b1a5496c6cecbf9.setIcon(icon_c7de65cc3ca2947c1f7892f141181003);
#
#
#         var popup_fee812dfd43db5751e5cbe059a222e8b = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_044821fa3be737d2e1c57bd68e48120f = $(`&lt;div id=&quot;ht

# %%
# !pip install flask folium
# Out:
# Requirement already satisfied: flask in /usr/local/lib/python3.11/dist-packages (3.1.0)
# Requirement already satisfied: folium in /usr/local/lib/python3.11/dist-packages (0.19.4)
# Requirement already satisfied: Werkzeug>=3.1 in /usr/local/lib/python3.11/dist-packages (from flask) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from flask) (3.1.5)
# Requirement already satisfied: itsdangerous>=2.2 in /usr/local/lib/python3.11/dist-packages (from flask) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from flask) (8.1.8)
# Requirement already satisfied: blinker>=1.9 in /usr/local/lib/python3.11/dist-packages (from flask) (1.9.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from folium) (0.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.11/dist-packages (from folium) (2025.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=3.1.2->flask) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2024.12.14)

# %%
from flask import Flask, render_template_string
import folium

app = Flask(__name__)

# List of most visited cities with locations
most_visited_cities = [
    {"rank": 1, "city": "Bangkok", "country": "Thailand", "visitors": 22.78, "lat": 13.7563, "lon": 100.5018},
    {"rank": 2, "city": "Paris", "country": "France", "visitors": 19.10, "lat": 48.8566, "lon": 2.3522},
    {"rank": 3, "city": "London", "country": "United Kingdom", "visitors": 19.09, "lat": 51.5074, "lon": -0.1278},
    {"rank": 4, "city": "Dubai", "country": "UAE", "visitors": 15.93, "lat": 25.276987, "lon": 55.296249},
    {"rank": 5, "city": "Singapore", "country": "Singapore", "visitors": 14.67, "lat": 1.3521, "lon": 103.8198},
]

# Create Folium Map
world_map = folium.Map(location=[20, 0], zoom_start=2, tiles="cartodb positron")

# Add city markers
for city in most_visited_cities:
    popup_text = f"""
    <b>{city['city']}, {city['country']}</b><br>
    🌍 Rank: {city['rank']}<br>
    👥 Visitors: {city['visitors']} Million
    """
    folium.Marker(
        location=[city["lat"], city["lon"]],
        popup=folium.Popup(popup_text, max_width=300),
        tooltip=f"{city['city']} (Click for details)",
        icon=folium.Icon(color="blue", icon="cloud")
    ).add_to(world_map)

# Save map as HTML
map_html = world_map._repr_html_()

@app.route('/')
def home():
    return render_template_string("""
    <html>
        <head>
            <title>Most Visited Cities</title>
        </head>
        <body>
            <h2>Interactive World Map</h2>
            {{ map_html|safe }}
        </body>
    </html>
    """, map_html=map_html)

if __name__ == '__main__':
    app.run(host='0.0.0.0', port=5000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.28.0.12:5000
# INFO:werkzeug:Press CTRL+C to quit

# %%
from flask import Flask, render_template_string
import folium

app = Flask(__name__)

# Most visited cities data
most_visited_cities = [
    {"rank": 1, "city": "Bangkok", "country": "Thailand", "visitors": 22.78, "lat": 13.7563, "lon": 100.5018},
    {"rank": 2, "city": "Paris", "country": "France", "visitors": 19.10, "lat": 48.8566, "lon": 2.3522},
    {"rank": 3, "city": "London", "country": "United Kingdom", "visitors": 19.09, "lat": 51.5074, "lon": -0.1278},
    {"rank": 4, "city": "Dubai", "country": "UAE", "visitors": 15.93, "lat": 25.276987, "lon": 55.296249},
    {"rank": 5, "city": "Singapore", "country": "Singapore", "visitors": 14.67, "lat": 1.3521, "lon": 103.8198},
    {"rank": 6, "city": "New York", "country": "USA", "visitors": 13.60, "lat": 40.7128, "lon": -74.0060},
    {"rank": 7, "city": "Kuala Lumpur", "country": "Malaysia", "visitors": 13.43, "lat": 3.1390, "lon": 101.6869},
    {"rank": 8, "city": "Tokyo", "country": "Japan", "visitors": 12.93, "lat": 35.682839, "lon": 139.759455},
    {"rank": 9, "city": "Istanbul", "country": "Turkey", "visitors": 12.80, "lat": 41.0082, "lon": 28.9784},
    {"rank": 10, "city": "Seoul", "country": "South Korea", "visitors": 11.25, "lat": 37.5665, "lon": 126.9780},
]

# Create a folium map
world_map = folium.Map(location=[20, 0], zoom_start=2, tiles="cartodb positron")

# Add city markers
for city in most_visited_cities:
    popup_text = f"""
    <b>{city['city']}, {city['country']}</b><br>
    🌍 Rank: {city['rank']}<br>
    👥 Visitors: {city['visitors']} Million
    """
    folium.Marker(
        location=[city["lat"], city["lon"]],
        popup=folium.Popup(popup_text, max_width=300),
        tooltip=f"{city['city']} (Click for details)",
        icon=folium.Icon(color="blue", icon="cloud")
    ).add_to(world_map)

# Get map HTML
map_html = world_map._repr_html_()

# Flask Route
@app.route('/')
def home():
    return render_template_string("""
    <html>
        <head>
            <title>Most Visited Cities</title>
            <meta name="viewport" content="width=device-width, initial-scale=1">
            <style>
                body { font-family: Arial, sans-serif; text-align: center; }
                h2 { color: #2C3E50; }
                .map-container { width: 100%; height: 600px; }
                iframe { width: 90%; height: 90vh; border: none; }
                .share-btn {
                    background: #25D366; color: white; padding: 10px 20px; border: none;
                    font-size: 16px; cursor: pointer; border-radius: 5px;
                }
            </style>
        </head>
        <body>
            <h2>Interactive World Map</h2>
            <button class="share-btn" onclick="shareOnWhatsApp()">📲 Share on WhatsApp</button>
            <br><br>
            {{ map_html|safe }}
            <script>
                function shareOnWhatsApp() {
                    let text = "Check out the most visited cities: https://yourappname.onrender.com";
                    let url = "https://wa.me/?text=" + encodeURIComponent(text);
                    window.open(url, "_blank");
                }
            </script>
        </body>
    </html>
    """, map_html=map_html)

# Run Flask App
if __name__ == '__main__':
    app.run(host='0.0.0.0', port=5000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.28.0.12:5000
# INFO:werkzeug:Press CTRL+C to quit

# %%
# !python app.py
